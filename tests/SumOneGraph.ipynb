# %% [markdown]
# Plotando o gráfico:

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# plot the data from busca_largura_tempos.txt, which is separated as "[number]; [time]"
# do the same for busca_profundidade10_tempos.txt, busca_profundidade100_tempos.txt and busca_profundidade_iterativa_tempos.txt

# read the data
largura = pd.read_csv('busca_largura_tempos.txt', sep='; ', engine='python', header=None)
profundidade10 = pd.read_csv('busca_profundidade10_tempos.txt', sep='; ', engine='python', header=None)
profundidade100 = pd.read_csv('busca_profundidade100_tempos.txt', sep='; ', engine='python', header=None)
iterativa = pd.read_csv('busca_profundidade_iterativa_tempos.txt', sep='; ', engine='python', header=None)

# %%
largura.columns = ['number', 'time']
profundidade10.columns = ['number', 'time']
profundidade100.columns = ['number', 'time']
iterativa.columns = ['number', 'time']

# %%
def convert_time_to_float(time_str):
    parts = time_str.split(':')
    hours = int(parts[0])
    minutes = int(parts[1])
    seconds_and_milliseconds = parts[2].split('.')
    seconds = int(seconds_and_milliseconds[0])
    total_seconds = hours * 3600 + minutes * 60 + seconds
    return total_seconds

# %%
for i in range(len(largura)):
    largura['time'][i] = convert_time_to_float(largura['time'][i])
# Out:
# C:\Users\pache\AppData\Local\Temp\ipykernel_13652\3342916472.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   largura['time'][i] = convert_time_to_float(largura['time'][i])
# C:\Users\pache\AppData\Local\Temp\ipykernel_13652\3342916472.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   largura['time'][i] = convert_time_to_float(largura['time'][i])
# C:\Users\pache\AppData\Local\Temp\ipykernel_13652\3342916472.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# plot the data using plt
plt.figure(figsize=(10, 5))
plt.plot(largura['number'], largura['time'], label='largura')
plt.plot(profundidade10['number'], profundidade10['time'], label='profundidade10')
plt.plot(profundidade100['number'], profundidade100['time'], label='profundidade100')
plt.plot(iterativa['number'], iterativa['time'], label='iterativa')
plt.legend()
plt.xlabel('Goals')
plt.xticks(np.arange(1, 51, 1))
plt.yticks(np.arange(0, 901, 100))
plt.ylabel('Time (s)')
plt.title('Time x Goals for each search method')
plt.show()

# %% [markdown]
# Nota: para a busca em Profundidade com m=10, da meta 22 em diante não há solução.

# %% [markdown]
# - Segundo o que discutimos em sala de aula, quais destes algoritmos são ótimos? Os resultado encontrados neste exercício são coerentes com está informação? Justifique a sua resposta.
#
#         Busca em Largura e Profundidade Iterativa são ótimos, pois encontram a solução com o menor número de passos possíveis.
#
#
# - Segundo o que discutimos em sala de aula, quais destes algoritmos são completos? Os resultado encontrados neste exercício são coerentes com está informação? Justifique a sua resposta.
#
#         Busca em Largura e Profundidade Iterativa são completos, pois encontram a solução caso ela exista.
#
#
# - Teve algum algoritmo que travou por falta de memória no seu computador? Se sim, qual é a explicação?
#
#         Nenhum deles chegou a travar, porém a busca em profundidade com m=10 não encontrou solução para a meta 22 em diante, e a busca em largura demandou bastante memória para encontrar as soluções maiores.
#
#
# - Qual é o algoritmo que tem um tempo de processamento menor? Justifique a sua resposta.
#
#         De acordo com o gráfico, a busca em profundidade em geral é mais rápida, já que neste tipo de problema a solução é encontrada mais rapidamente em uma profundidade menor.
